# %% [markdown]
# <!-- brand-header -->
# <div align="center">
#
# <img src="../../../1-Dragon-Motivation-Logo.png" alt="Shasu Vathanan - GEN AI - Product Manager" width="80">
#
# # Build a Simple Streamlit App
#
# **Shasu Vathanan - GEN AI - Product Manager**
#
# [![Website](https://img.shields.io/badge/Website-SHASUVATHANAN.COM-FF4A62?style=for-the-badge)](https://shasuvathanan.com)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-shasuvathanan-031273?style=for-the-badge&logo=linkedin&logoColor=white)](https://www.linkedin.com/in/shasuvathanan)
#
# </div>
#
# $\textcolor{#FF4A62}{\rule{26em}{4pt}}$
#
# *Notebook 3 of 3 &nbsp;·&nbsp; Streamlit Resources*

# %% [markdown]
# # 3. Build a Simple Streamlit App
#
# Now let's combine what we learned and build a **complete mini app**.
#
# We will build a **BMI Calculator** (Body Mass Index) — it takes your weight and height and tells your BMI.
#
# > A ready-to-run file named **`app.py`** is included in this same folder. Run it with:
# > ```
# > streamlit run app.py
# > ```

# %% [markdown]
# ## Step 1: Plan the app
#
# Our app needs to:
# 1. Show a **title**.
# 2. Ask for **weight** (in kg).
# 3. Ask for **height** (in meters).
# 4. Have a **button** to calculate.
# 5. Show the **BMI result**.

# %% [markdown]
# ## Step 2: The complete code
#
# Copy this code into a file named `app.py` (or use the one already provided), then run `streamlit run app.py`.

# %%
import streamlit as st

# 1. Title
st.title("BMI Calculator")
st.write("Enter your details to calculate your BMI.")

# 2. Get inputs from the user
weight = st.number_input("Enter your weight (kg):", min_value=1.0)
height = st.number_input("Enter your height (meters):", min_value=0.1)

# 3. Button to calculate
if st.button("Calculate BMI"):
    bmi = weight / (height * height)
    st.write("Your BMI is:", round(bmi, 2))

    # 4. Give a message based on the result
    if bmi < 18.5:
        st.warning("You are underweight.")
    elif bmi < 25:
        st.success("You have a normal weight. 👍")
    else:
        st.error("You are overweight.")

# %% [markdown]
# ## Step 3: Understanding the code
#
# - `st.title()` → shows the app heading.
# - `st.number_input()` → asks the user for numbers.
# - `st.button("Calculate BMI")` → the code inside runs only when clicked.
# - `bmi = weight / (height * height)` → the BMI formula.
# - `if / elif / else` → shows a different message based on the BMI value.
# - `st.success / warning / error` → colored result messages.

# %% [markdown]
# ## Step 4: Run it!
#
# 1. Open the terminal in this folder.
# 2. Type:
#    ```
#    streamlit run app.py
#    ```
# 3. Your app opens in the browser.
# 4. Enter weight and height, click **Calculate BMI**, and see the result.

# %% [markdown]
# ## Bonus: Another mini app idea (Greeting App)
#
# Try building this on your own as practice:
#
# ```python
# import streamlit as st
#
# st.title("Greeting App")
# name = st.text_input("What is your name?")
#
# if st.button("Greet me"):
#     st.success("Hello " + name + "! Welcome. 🎉")
# ```

# %% [markdown]
# ## Key points to remember
#
# - A real app combines **text + inputs + button + logic**.
# - Use `st.button()` to trigger the calculation.
# - Use `if/elif/else` to show different results.
# - Always run the app with `streamlit run app.py`.
# - Practice by building small apps (calculator, greeting, etc.).

# %% [markdown]
# <!-- brand-header -->
# $\textcolor{#FF4A62}{\rule{20em}{2pt}}$
#
# <div align="center">
#
# **Created and Maintained by**
#
# ### Shasu Vathanan - GEN AI - Product Manager
#
# [SHASUVATHANAN.COM](https://shasuvathanan.com) &nbsp;&#8226;&nbsp; [LinkedIn](https://www.linkedin.com/in/shasuvathanan)
#
# </div>
