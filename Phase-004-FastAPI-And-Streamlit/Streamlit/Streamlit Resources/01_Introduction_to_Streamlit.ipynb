# %% [markdown]
# <!-- brand-header -->
# <div align="center">
#
# <img src="../../../1-Dragon-Motivation-Logo.png" alt="Shasu Vathanan - GEN AI - Product Manager" width="80">
#
# # Introduction to Streamlit
#
# **Shasu Vathanan - GEN AI - Product Manager**
#
# [![Website](https://img.shields.io/badge/Website-SHASUVATHANAN.COM-FF4A62?style=for-the-badge)](https://shasuvathanan.com)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-shasuvathanan-031273?style=for-the-badge&logo=linkedin&logoColor=white)](https://www.linkedin.com/in/shasuvathanan)
#
# </div>
#
# $\textcolor{#FF4A62}{\rule{26em}{4pt}}$
#
# *Notebook 1 of 3 &nbsp;·&nbsp; Streamlit Resources*

# %% [markdown]
# # 1. Introduction to Streamlit
#
# **Streamlit** is a free Python library used to build **web apps** quickly — without needing to know HTML, CSS, or JavaScript.
#
# With just simple Python code, you can create interactive websites, dashboards, and data apps.

# %% [markdown]
# ## Why use Streamlit?
#
# - ✅ **Very easy** — write only Python.
# - ✅ **Fast** — build an app in minutes.
# - ✅ **Interactive** — add buttons, sliders, charts easily.
# - ✅ **Popular** — widely used for Data Science and AI demos.
#
# ### Real examples of what you can build
# - A calculator app
# - A data dashboard with charts
# - A machine learning prediction app
# - A chatbot interface

# %% [markdown]
# ## Step 1: Install Streamlit
#
# Type this command in the **terminal** (not inside Python):
#
# ```
# pip install streamlit
# ```
#
# > Tip: Do this inside a virtual environment if you have one active.

# %% [markdown]
# ## Step 2: Write your first app
#
# Streamlit apps are saved as a **`.py`** file (NOT a notebook).
#
# Create a file called **`app.py`** and put this code inside it:
#
# ```python
# import streamlit as st
#
# st.title("My First Streamlit App")
# st.write("Hello! Welcome to Streamlit.")
# ```
#
# - `import streamlit as st` → loads Streamlit (we call it `st` for short).
# - `st.title()` → shows a big heading.
# - `st.write()` → shows text (or almost anything).

# %% [markdown]
# ## Step 3: Run the app
#
# In the terminal, type:
#
# ```
# streamlit run app.py
# ```
#
# This opens your app automatically in the **web browser** (usually at `http://localhost:8501`).
#
# To stop the app, press **Ctrl + C** in the terminal.

# %% [markdown]
# ## Important note about notebooks
#
# ⚠️ Streamlit apps do **NOT** run inside Jupyter notebook cells.
#
# You must:
# 1. Save the code in a `.py` file.
# 2. Run it with `streamlit run filename.py`.
#
# The code cell below is shown only as an example — it will not display a web app here.

# %%
# Example code (copy this into a file named app.py, then run: streamlit run app.py)
import streamlit as st

st.title("My First Streamlit App")
st.write("Hello! Welcome to Streamlit.")

# %% [markdown]
# ## Key points to remember
#
# - Streamlit builds web apps using only Python.
# - Install with `pip install streamlit`.
# - Save your app as a `.py` file.
# - Run it with `streamlit run app.py`.
# - `st.title()` shows a heading; `st.write()` shows text.
# - It opens in your web browser, not in a notebook.

# %% [markdown]
# <!-- brand-header -->
# $\textcolor{#FF4A62}{\rule{20em}{2pt}}$
#
# <div align="center">
#
# **Created and Maintained by**
#
# ### Shasu Vathanan - GEN AI - Product Manager
#
# [SHASUVATHANAN.COM](https://shasuvathanan.com) &nbsp;&#8226;&nbsp; [LinkedIn](https://www.linkedin.com/in/shasuvathanan)
#
# </div>
