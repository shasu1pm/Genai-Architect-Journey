# %% [markdown]
# # 6. Python Operators
#
# **Operators** are special symbols used to perform operations on values (like `+`, `-`, `*`).
#
# There are different types of operators in Python.

# %% [markdown]
# ## 1. Arithmetic Operators (Math)
#
# | Operator | Meaning | Example |
# |----------|---------|---------|
# | `+` | Addition | `5 + 2 = 7` |
# | `-` | Subtraction | `5 - 2 = 3` |
# | `*` | Multiplication | `5 * 2 = 10` |
# | `/` | Division | `5 / 2 = 2.5` |
# | `%` | Modulus (remainder) | `5 % 2 = 1` |
# | `//` | Floor division | `5 // 2 = 2` |
# | `**` | Power | `5 ** 2 = 25` |

# %%
a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Remainder:", a % b)
print("Power:", a ** b)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Remainder: 1
# Power: 1000

# %% [markdown]
# ## 2. Comparison Operators
#
# They compare two values and give `True` or `False`.
#
# | Operator | Meaning |
# |----------|---------|
# | `==` | Equal to |
# | `!=` | Not equal to |
# | `>` | Greater than |
# | `<` | Less than |
# | `>=` | Greater than or equal |
# | `<=` | Less than or equal |

# %%
x = 10
y = 20

print(x == y)   # is x equal to y?
print(x != y)   # is x not equal to y?
print(x < y)    # is x less than y?
print(x > y)    # is x greater than y?
# Out:
# False
# True
# True
# False

# %% [markdown]
# ## 3. Logical Operators
#
# Used to combine conditions.
#
# | Operator | Meaning |
# |----------|---------|
# | `and` | True if **both** are true |
# | `or` | True if **any one** is true |
# | `not` | Reverses the result |

# %%
age = 25

print(age > 18 and age < 60)   # both must be true
print(age < 10 or age > 18)    # any one true is enough
print(not(age > 18))           # reverses True to False
# Out:
# True
# True
# False

# %% [markdown]
# ## 4. Assignment Operators
#
# Used to give values to variables.
#
# `=` assigns, `+=` adds and assigns, and so on.

# %%
score = 10
print(score)

score += 5   # same as: score = score + 5
print(score)

score -= 2   # same as: score = score - 2
print(score)
# Out:
# 10
# 15
# 13

# %% [markdown]
# ## Key points to remember
#
# - **Arithmetic**: `+ - * / % // **` for math.
# - **Comparison**: `== != > < >= <=` give True/False.
# - **Logical**: `and`, `or`, `not` combine conditions.
# - **Assignment**: `=`, `+=`, `-=` store values.
